# %%
# !pip install nltk
import nltk
from nltk.util import ngrams
from collections import Counter
import re
# Out:
# ...
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x0000026179F32FF0>>
# Traceback (most recent call last):
#   File "C:\Users\Angie\miniconda3\Lib\site-packages\ipykernel\ipkernel.py", line 790, in _clean_thread_parent_frames
#     active_threads = {thread.ident for thread in threading.enumerate()}
#                                                  ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Angie\miniconda3\Lib\threading.py", line 1533, in enumerate
#     def enumerate():
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 get_ipython().system('pip install nltk')
# ----> 2 import nltk
#       3 from nltk.util import ngrams
#       4 from collection import Counter
#
# File ~\miniconda3\Lib\site-packages\nltk\__init__.py:146
# ...
