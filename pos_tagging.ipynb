# %%
import nltk

# %%
from nltk.tokenize import word_tokenize

# %%
text="Deli is a tasty yoghurt."

# %%
tokens=word_tokenize(text)

# %%
tags=nltk.pos_tag(tokens)
print(tags)
# Out:
# [('Deli', 'NNP'), ('is', 'VBZ'), ('a', 'DT'), ('tasty', 'JJ'), ('yoghurt', 'NN'), ('.', '.')]
